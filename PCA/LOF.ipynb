# %%
from google.colab import drive
drive.mount('/content/drive')


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

data1=pd.read_csv('/content/drive/MyDrive/280k_data/ack_h.csv')
data2=pd.read_csv('/content/drive/MyDrive/280k_data/benign_traffic_h.csv')
data3=pd.read_csv('/content/drive/MyDrive/280k_data/junk_h.csv')
data4=pd.read_csv('/content/drive/MyDrive/280k_data/scan_h.csv')
data5=pd.read_csv('/content/drive/MyDrive/280k_data/syn_h.csv')
data6=pd.read_csv('/content/drive/MyDrive/280k_data/tcp_h.csv')
data7=pd.read_csv('/content/drive/MyDrive/280k_data/udp_h.csv')
data8=pd.read_csv('/content/drive/MyDrive/280k_data/udpplain_h.csv')


data1['class']='ack'
data2['class']='benign'
data3['class']='junk'
data4['class']='scan'
data5['class']='syn'
data6['class']='tcp'
data7['class']='udp'
data8['class']='udpplain'


data=pd.concat([data1,data2,data3,data4,data5,data6,data7,data8],

               axis=0, sort=False, ignore_index=True)

data.groupby('class')['class'].count()
data
# Out:
# Mounted at /content/drive
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.996585      566.000000        5.820000e-11
# 2               2.958989      566.000000        0.000000e+00
# 3               3.958979      566.000000        0.000000e+00
# 4               4.914189      566.000000        1.160000e-10
# ...                  ...             ...                 ...
# 279987         39.256165      504.003978        2.219839e+04
# 279988         40.255905      505.245933        2.170751e+04
# 279989         41.255606      506.427690        2.123756e+04
# 279990         42.255469      507.553516        2.078725e+04
# 279991         43.240249      508.627665        2.035525e+04
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.997950      566.000000        5.820000e-11
# ...

# %%
data.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count     279992.000000   279992.000000       279992.000000     279992.000000
# mean          73.627523      145.198867        12792.355289        117.257552
# std           69.062592      147.738904        24951.036740        110.445957
# min            1.000000       60.000000            0.000000          1.000000
# 25%            1.000000       60.000000            0.000000          1.000000
# 50%           69.204638       74.019857            3.239701        104.829868
# 75%          136.714394      182.721613        16301.952410        215.950860
# max          281.027182     1452.697092       467824.033100        374.233854
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count   279992.000000       279992.000000     279992.000000   279992.000000
# mean       145.713066        14322.556861        330.822217      146.578753
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279992 entries, 0 to 279991
# Columns: 116 entries, MI_dir_L5_weight to class
# dtypes: float64(115), object(1)
# memory usage: 247.8+ MB

# %%
Labels = data['class']
data = data.drop(['class'], axis = 1)
Labels = np.array(Labels)
Labels
# Out:
# array(['ack', 'ack', 'ack', ..., 'udpplain', 'udpplain', 'udpplain'],
#       dtype=object)

# %%
'''from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\ndata_scaled = scaler.fit_transform(data)'

# %%
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(n_neighbors=100, contamination=0.5)
y_pred = clf.fit_predict(data)

# %%
y_pred
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
lofs_index = (y_pred==-1)
values = data[lofs_index]
values
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.996585      566.000000        5.820000e-11
# 2               2.958989      566.000000        0.000000e+00
# 3               3.958979      566.000000        0.000000e+00
# 4               4.914189      566.000000        1.160000e-10
# ...                  ...             ...                 ...
# 279987         39.256165      504.003978        2.219839e+04
# 279988         40.255905      505.245933        2.170751e+04
# 279989         41.255606      506.427690        2.123756e+04
# 279990         42.255469      507.553516        2.078725e+04
# 279991         43.240249      508.627665        2.035525e+04
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.997950      566.000000        5.820000e-11
# ...

# %%
from sklearn import metrics
metrics.silhouette_score(data, y_pred)
# Out:
# -0.04433600748831171

# %%
from sklearn import metrics
metrics.calinski_harabasz_score(data, y_pred)
# Out:
# 8028.62074493732

# %%
outlier_index = (y_pred == -1) 
outlier_values = data.iloc[outlier_index]

# %%
outlier_values
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.996585      566.000000        5.820000e-11
# 2               2.958989      566.000000        0.000000e+00
# 3               3.958979      566.000000        0.000000e+00
# 4               4.914189      566.000000        1.160000e-10
# ...                  ...             ...                 ...
# 279987         39.256165      504.003978        2.219839e+04
# 279988         40.255905      505.245933        2.170751e+04
# 279989         41.255606      506.427690        2.123756e+04
# 279990         42.255469      507.553516        2.078725e+04
# 279991         43.240249      508.627665        2.035525e+04
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000      566.000000        0.000000e+00
# 1               1.997950      566.000000        5.820000e-11
# ...

# %% [markdown]
# **silhouette Score Visualization**

# %%
#S_8
import matplotlib.pyplot as plt
y=[0.56311,-0.90264,0.99292,0.75223,0.84735,0.4437]
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
plt.ylim(-1,1)
plt.xlabel('Algorithms')
plt.ylabel('Silhoutte Score')
plt.show()

# %%
#S_6
import matplotlib.pyplot as plt
y=[0.52805,-0.09793,0.99527,0.80000,0.74864,0.4172]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
plt.ylim(-1,1)
plt.xlabel('Algorithms')
plt.ylabel('silhouette score')
plt.show()

# %%
#S_4
import matplotlib.pyplot as plt
y=[0.45250,-0.62304,0.99538,0.80390,0.655535,0.4023]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
plt.ylim(-1,1)
plt.xlabel('Algorithms')
plt.ylabel('silhouette score')
plt.show()

# %%
#S_2
import matplotlib.pyplot as plt
y=[0.54218,0.16457,0.97996,0.56166,0.671945,0.42234]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
plt.ylim(-1,1)
plt.xlabel('Algorithms')
plt.ylabel('silhouette score')
plt.show()

# %%
#algorithms which can't defined clusters

import matplotlib.pyplot as plt
y=[-0.04433,0.69707,0.75568,0.909,]
 
x=['LOF','DBSCAN','OPTICS','Mean Shift']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
#plt.ylim(1000,90000)
plt.xlabel('Algorithms')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# **Calinski Harabasz Visualization**

# %%
#C_8
import matplotlib.pyplot as plt
y=[64976.1970,3315.70772,486876.2094,74622.06400,112858.10036,35236.87343]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
#plt.ylim(1000,90000)
plt.xlabel('Algorithms')
plt.ylabel('Calinski-Harabasz Score')
plt.show()

# %%
#C_6
import matplotlib.pyplot as plt
y=[30319.5076,3463.53435,759894.99656,154924.95258,224887.66751,10232.7823]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
#plt.ylim(1000,90000)
plt.xlabel('Algorithms')
plt.ylabel('Calinski-Harabasz Score')
plt.show()

# %%
#C_4
import matplotlib.pyplot as plt
y=[12560.2063,3457.50935,187775.55920,35495.42827,60944.78049,8565.5656]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
plt.ylim(1000,200000)
plt.xlabel('Algorithms')
plt.ylabel('Calinski-Harabasz Score')
plt.show()

# %%
#C_2
import matplotlib.pyplot as plt
y=[104974.4174,9833.94318,517450.32621,28229.17189,497299.38464,20565.45634]
 
x=['KMeans','EM_G','Fuzzy C Means','PCA','BIRCH','Hierarchical']
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083','orange','#03f0fc'),edgecolor='blue')
#plt.ylim(1000,90000)
plt.xlabel('Algorithms')
plt.ylabel('Calinski-Harabasz Score')
plt.show()

# %%
#algorithms which can't defined clusters

import matplotlib.pyplot as plt
y=[8028.62074,1244719.14758,2125874.34778,8914430.48311]   
 
x=['LOF','DBSCAN','OPTICS','Mean Shift']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(1000,900000)
plt.xlabel('Algorithms')
plt.ylabel('Calinski-Harabasz Score')
plt.show()

# %% [markdown]
# **Adjusted Rand Index**

# %%
#AR_8

import matplotlib.pyplot as plt
y=[0.020408166224,0.1675910550208,0.0204429353569,0.7494393856986,1.0,0.019425564]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']   
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()

# %%
#AR_6

import matplotlib.pyplot as plt
y=[0.020260630434,0.2224037919707,0.0203723709269,0.749536521689,0.764701383852,0.01123542532]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     

plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()

# %%
#AR_4

import matplotlib.pyplot as plt
y=[0.020207088511,0.05275495677,0.02019881847,0.5348416544,0.534877501008,0.010152585]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']    
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()

# %%
#AR_2

import matplotlib.pyplot as plt
y=[0.027752498197,0.130028376018,0.0277258376,0.22387625289,0.07692130171,0.01012135878]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()

# %%
#algorithms which can't defined clusters

import matplotlib.pyplot as plt
y=[0.0495069814992,0.856323896204,0.86376369976,0.02025980160992]   
 
x=['LOF','DBSCAN','OPTICS','Mean Shift']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()

# %% [markdown]
# ***Fowlkes-Mallows***

# %%
#FM_8
import matplotlib.pyplot as plt
y=[0.3493634532391,0.38182038692,0.34933803729,0.825477859924,1.0,0.31156836689]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Fowlkes-Mallows Score')
plt.show()

# %%
#FM_6
import matplotlib.pyplot as plt
y=[0.349467391609,0.3815535135831,0.3493856901342,0.803432394470,0.81649269265,0.326589673563]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Fowlkes-Mallows Score')
plt.show()

# %%
#FM_4
import matplotlib.pyplot as plt
y=[0.34968269052,0.299429994031,0.34969404553,0.666624341393,0.666661375422,0.3421342138]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Fowlkes-Mallows Score')
plt.show()

# %%
#FM_2
import matplotlib.pyplot as plt
y=[0.359439330912,0.380047430420,0.35942282321,0.48506595075,0.399995199812,0.299936367357]   
 
x=['KMeans','EM','Fuzzy C Means','PCA','BIRCH','Hierarchical']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Fowlkes-Mallows Score')
plt.show()

# %%
#algorithms which can't defined clusters

import matplotlib.pyplot as plt
y=[0.301397346540,0.88022158478,0.887555052981,0.3494577364320]   
 
x=['LOF','DBSCAN','OPTICS','Mean Shift']     
 
plt.figure(figsize=(6,8))
z= range(len(y))
plt.bar(x,y,0.6,color=('#f03e3e','#6a65f7','#b3177c','#3fb083'),edgecolor='blue')
plt.ylim(0,1)
plt.xlabel('Algorithms')
plt.ylabel('Adjusted Rand Index Score')
plt.show()
